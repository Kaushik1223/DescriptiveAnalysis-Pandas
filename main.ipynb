# %% [markdown]
# # Descriptive Analysis on Anime dataset using Pandas
# ###### Dataset used: https://www.kaggle.com/datasets/CooperUnion/anime-recommendations-database
# ### First load the datset into a Pandas DataFrame using the read_csv() function. Then use various functions to analyze the data.
# <hr>

# %% [markdown]
# ## Importing
# ### 1. Pandas (working with data sets)
# ### 2. Matplotlib (to create static, animated, and interactive visualizations)
# ### 3. Seaborn (to visualize random distributions)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('anime.csv')

# %% [markdown]
# ### Display Top 15 rows of the Dataset

# %%
data.head(15)
# Out:
#     Anime_ID                                               Name  \
# 0      32281                                     Kimi no Na wa.
# 1       5114                   Fullmetal Alchemist: Brotherhood
# 2      28977                                           Gintama°
# 3       9253                                        Steins;Gate
# 4       9969                                      Gintama&#039;
# 5      32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6      11061                             Hunter x Hunter (2011)
# 7        820                               Ginga Eiyuu Densetsu
# 8      15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9      15417                           Gintama&#039;: Enchousen
# 10      4181                               Clannad: After Story
# 11     28851                                     Koe no Katachi
# 12       918                                            Gintama
# 13      2904                 Code Geass: Hangyaku no Lelouch R2
# ...

# %% [markdown]
# ### Dispay Last 10 rows of the Dataset

# %%
data.tail(10)
# Out:
#        Anime_ID                                               Name  \
# 12284     26031                                 Super Erotic Anime
# 12285     34399                                   Taimanin Asagi 3
# 12286     10368                                Teleclub no Himitsu
# 12287      9352                             Tenshi no Habataki Jun
# 12288      5541                                   The Satisfaction
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                               Genre   Type Episodes  Rating  Members
# 12284                        Hentai    OVA        2    4.45      118
# 12285  Demons, Hentai, Supernatural    OVA  Unknown     NaN      485
# ...

# %% [markdown]
# ### Shape of Dataset (No. of Rows & Columns)

# %%
data.shape
# Out:
# (12294, 7)

# %%
print("No. of Rows: ",data.shape[0])
print("No. of Column: ",data.shape[1])
# Out:
# No. of Rows:  12294
# No. of Column:  7

# %% [markdown]
# ### Information about Dataset (Datatype of each column, Memory Requiremnet)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Anime_ID  12294 non-null  int64
#  1   Name      12294 non-null  object
#  2   Genre     12232 non-null  object
#  3   Type      12269 non-null  object
#  4   Episodes  12294 non-null  object
#  5   Rating    12064 non-null  float64
#  6   Members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %% [markdown]
# ### Check Missing Values in Dataset

# %%
data.isnull().sum()
# Out:
# Anime_ID      0
# Name          0
# Genre        62
# Type         25
# Episodes      0
# Rating      230
# Members       0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Overall Stats

# %%
data.describe()
# Out:
#            Anime_ID        Rating       Members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %% [markdown]
# ## Ratings Chart
# ### (Top 10 Anime based on User Ratings)

# %%
data.columns
# Out:
# Index(['Anime_ID', 'Name', 'Genre', 'Type', 'Episodes', 'Rating', 'Members'], dtype='object')

# %%
data.head(10).groupby('Name')['Rating'].mean().sort_values(ascending=False)
# Out:
# Name
# Kimi no Na wa.                                               9.37
# Fullmetal Alchemist: Brotherhood                             9.26
# Gintama°                                                     9.25
# Steins;Gate                                                  9.17
# Gintama&#039;                                                9.16
# Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou    9.15
# Hunter x Hunter (2011)                                       9.13
# Ginga Eiyuu Densetsu                                         9.11
# Gintama&#039;: Enchousen                                     9.11
# Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare          9.10
# Name: Rating, dtype: float64

# %%
sns.barplot(x='Rating', y='Name',data=data.head(10))
plt.title("Ratings Chart")
plt.show()

# %% [markdown]
# ## Highest Episodes
# ### (Sort Anime based on no. of episodes)

# %%
data.columns
# Out:
# Index(['Anime_ID', 'Name', 'Genre', 'Type', 'Episodes', 'Rating', 'Members'], dtype='object')

# %%
data.head(10).groupby('Name')['Episodes'].mean().sort_values(ascending=False)
# Out:
# Name
# Hunter x Hunter (2011)                                       148.0
# Ginga Eiyuu Densetsu                                         110.0
# Fullmetal Alchemist: Brotherhood                              64.0
# Gintama&#039;                                                 51.0
# Gintama°                                                      51.0
# Steins;Gate                                                   24.0
# Gintama&#039;: Enchousen                                      13.0
# Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou     10.0
# Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare            1.0
# Kimi no Na wa.                                                 1.0
# Name: Episodes, dtype: float64

# %%
sns.scatterplot(x='Episodes',y='Name',data=data.head(20))
plt.title("Episode Chart")
plt.show()

# %% [markdown]
# ## Member Count Chart (Based on MyAnimeList)
# ### (Count total no. of members on MyAnimeList)

# %%
data.columns
# Out:
# Index(['Anime_ID', 'Name', 'Genre', 'Type', 'Episodes', 'Rating', 'Members'], dtype='object')

# %%
data.head(20).groupby('Name')['Members'].mean().sort_values(ascending=False)
# Out:
# Name
# Fullmetal Alchemist: Brotherhood                             793665.0
# Code Geass: Hangyaku no Lelouch                              715151.0
# Steins;Gate                                                  673572.0
# Code Geass: Hangyaku no Lelouch R2                           572888.0
# Sen to Chihiro no Kamikakushi                                466254.0
# Clannad: After Story                                         456749.0
# Hunter x Hunter (2011)                                       425855.0
# Shigatsu wa Kimi no Uso                                      416397.0
# Gintama                                                      336376.0
# Ookami Kodomo no Ame to Yuki                                 226193.0
# Kimi no Na wa.                                               200630.0
# Haikyuu!! Second Season                                      179342.0
# Gintama&#039;                                                151266.0
# ...

# %%
sns.barplot(x='Members', y='Name',data=data.head(10))
plt.title("Member Count")
plt.show()

# %% [markdown]
# ### Members vs Ratings Chart (Scatterplot)

# %%
data.columns
# Out:
# Index(['Anime_ID', 'Name', 'Genre', 'Type', 'Episodes', 'Rating', 'Members'], dtype='object')

# %%
sns.scatterplot(x='Members',y='Rating',data=data.head(10))
# Out:
# <AxesSubplot: xlabel='Members', ylabel='Rating'>
